# %% [markdown]
# # MSIS Program in California Factsheet
# Student Name: Neha Pawar

# %% [markdown]
# # Claim:

# %% [markdown]
# SCU MSIS in the best program in California for MSIS aspirants!

# %% [markdown]
#  # Visualization to be redesigned

# %%
from IPython.display import Image
Image("/Users/MyMac/Desktop/LAB8/Screenshots/LAB5_viz.png")

# %% [markdown]
# # Problems with this visualization:

# %% [markdown]
# "Seriously ! What was I thinking" This was my first reaction when I looked at LAB5 visualization.
#
# PFB Critique of existing dashboard:
#
# 1. Title, data source as reference and Assumptions are not mentioned.
# 2. This visualization only presents available raw data.
# 3. One does not understand what is the claim of this visualization.
# 4. It just looks like different metrics combined in one dashboard without any connection or integration.
# 5. No target audience specified.
# 6. One can not comprehend anything fruitful as it is just raw data presentation.

# %% [markdown]
# # Roadmap for redesigning this visualization:

# %% [markdown]
# To redesign existing visualization, first I started thinking about Claim, Target Audience and Important Metrics to rate MSIS program. Also, I considered actions I took before I decided to join SCU MSIS.
#
# <b> Target Audience: </b> This visualization is intended for Prospective Students for SCU MSIS program.
#
# <b> Metrics on MSIS program: </b>
# 1. Program Ranking
# 2. Course Curriculum
# 3. Required Skillset for prospective job profiles
# 4. Job Demographics
# 5. University Acceptance Rate
# 6. Average test scores
# 7. Employment rates within 3 to 6 months of graduation
# 8. Alumni work data
# 9. Student Teacher Ratio
# 10. Weather
# 11. Safety
#
# University Ranking along with Course Curriculum, Required Skillset for prospective job profiles, Job Demographics, University Acceptance rate along with average test scores, Employment rates within 6 months of graduation along with alumni work data, Student Teacher Ratio are the important deciding factors while selecting School and Program.
#
# After analyzing the dataset, I picked University Rankings along with Student Teacher Ratio as integrated metric to show California MSIS program ratings.
#
# I sliced ranking dataset to remove Stanford and Berkeley Universities, after comparing the average test scores and student profiles of these universities with SCU MSIS current class profle and test scores.
#
# 2017 Fall MSIS entering class profile:
#
# 1. Average age : 25
# 2. Women : 61%
# 3. Average undergraduate : GPA 3.26
# 4. Average GMAT or GRE  : 644 / 307
# 5. Average TOEFL : 102
#
# SCU MSIS ranks 2nd in terms of Student-Teacher ratio of 14:1, which shows that students can get better attention from teachers which helps in improving student skillset.
#
# Another metric that I picked is SCU MSIS course curriculum mapped with Data Science Required Skills from Linkedin. If we compare Data Science skillset to SCU MSIS course curriculum, it shows that SCU MSIS graduates will be well equipped with the skillset required to succeed in Data Science field.
#
# As per the PWC analytics publications, Analyst job opportunities are more available in California, which makes SCU MSIS program more desirable as SCU is based in the heart of Silicon Valley.
#
# SCU MSIS alumni work in leading organizations like Facebook, NVidia, Apple.
#
# From Student point of view, all the above parameters collectively prove that SCU MSIS graduate students are competitive and also they can sustain in dynamic and fast paced work environment as SCU MSIS is on quarter system with a competitive course curriculum.
#
# I have presented couple of integrated metrics in the improved visualization and to give a better picture.

# %% [markdown]
# # Redesigned Visualization:

# %%
Image("/Users/MyMac/Desktop/LAB8/Screenshots/LAB8_Final_Version.png")

# %% [markdown]
# Tableau Public Link:
#
# https://public.tableau.com/profile/neha4079#!/vizhome/MSISPrograminCaliforniaFactsheet/Dashboard2?publish=yes

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Looking at redesigned visualization, one can comprehend that SCU MSIS ranks the highest in California and their Student Teacher ratio is among the best ones.
#
# Also, I have mapped required Data Science job skills with SCU MSIS course curriculum. It shows SCU MSIS graduates will be well equipped with the skillset required to succeed in Data Science field.
#
# Hence, one can conclude, SCU MSIS is the best program in California for Data Science Aspirants.
#
# <b> Notes: </b>
#
# Fist chart in Dashboard shows MSIS programs in California as per University Rankings mapped along with Student Teacher Ratio to give an integrated view of California university MSIS programs.
#
# I have taken inverse of university ranking number to map rather than showing original number, as original rankings displayed in bar chart give deceptive picture.
#
# Datasets are taken from LAB4 assignment where we used beautifulsoup to perform web scrapping. Jupyter notebook for the same is added in Github repository for LAB8.

# %% [markdown]
# References:
#
# https://www.scu.edu/business/ms-information-systems/
#
# https://www.pwc.com/us/en/publications/data-science-and-analytics.html
